# %%
from sklearn import datasets
import matplotlib.pyplot as plt

boston = datasets.load_boston()
x = boston.data
y = boston.target

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
lstat = x[0:,-1]
lstat.shape
# Out:
# (506,)

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(lstat, y)

# %%
print(slope, intercept, r_value, p_value, std_err)
# Out:
# -0.9500493537579909 34.55384087938311 -0.7376627261740147 5.081103394388519e-88 0.03873341621263944

# %%
print("r-squared:", r_value**2)
# Out:
# r-squared: 0.5441462975864795

# %%
plt.plot(lstat, y, 'o',label='original data')
plt.plot(lstat, intercept + slope*lstat, 'r', label='fitted line')
plt.show()

# %%
rm = x[0:,5]

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(rm, y)

# %%
print(slope, intercept, r_value, p_value, std_err)
# Out:
# 9.102108981180306 -34.67062077643854 0.695359947071539 2.487228871008377e-74 0.41902656012134054

# %%
print("r-squared:", r_value**2)
# Out:
# r-squared: 0.48352545599133356

# %%
plt.plot(rm, y, 'o', label='original data')
plt.plot(rm, intercept+slope*rm, 'r', label='fitted line')
plt.legend()
plt.show()

# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes = datasets.load_diabetes()

df = pd.DataFrame(disabetes.data, columns=diabetes.feature_names)
dataset.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df['Target'] = diabetes.target

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# 3  0.034309  0.022692 -0.009362   206.0
# 4 -0.002592 -0.031991 -0.046641   135.0

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#            Target
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000

# %%
plt.hist(df['Target'])
# Out:
# (array([38., 80., 68., 62., 50., 41., 38., 42., 17.,  6.]),
#  array([ 25. ,  57.1,  89.2, 121.3, 153.4, 185.5, 217.6, 249.7, 281.8,
#         313.9, 346. ]),
#  <a list of 10 Patch objects>)

# %%
numeric_cols = [col for col in df.columns if col != 'sex']

# %%
numeric_cols
# Out:
# ['age', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6', 'Target']

# %%
df[numeric_cols].hist(figsize=(20,20),bins=30, xlabelsize=12, ylabelsize=12)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d331ab290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d331abd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d3315e510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d3317bd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d33120550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d3313ed10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d330e2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d330ffd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d331058d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d330c6290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d330315d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d32fe4dd0>]],
#       dtype=object)

# %%
df[numeric_cols].corr()
# Out:
#              age       bmi        bp        s1        s2        s3        s4  \
# age     1.000000  0.185085  0.335427  0.260061  0.219243 -0.075181  0.203841
# bmi     0.185085  1.000000  0.395415  0.249777  0.261170 -0.366811  0.413807
# bp      0.335427  0.395415  1.000000  0.242470  0.185558 -0.178761  0.257653
# s1      0.260061  0.249777  0.242470  1.000000  0.896663  0.051519  0.542207
# s2      0.219243  0.261170  0.185558  0.896663  1.000000 -0.196455  0.659817
# s3     -0.075181 -0.366811 -0.178761  0.051519 -0.196455  1.000000 -0.738493
# s4      0.203841  0.413807  0.257653  0.542207  0.659817 -0.738493  1.000000
# s5      0.270777  0.446159  0.393478  0.515501  0.318353 -0.398577  0.617857
# s6      0.301731  0.388680  0.390429  0.325717  0.290600 -0.273697  0.417212
# Target  0.187889  0.586450  0.441484  0.212022  0.174054 -0.394789  0.430453
#
#               s5        s6    Target
# age     0.270777  0.301731  0.187889
# bmi     0.446159  0.388680  0.586450
# bp      0.393478  0.390429  0.441484
# s1      0.515501  0.325717  0.212022
# s2      0.318353  0.290600  0.174054
# s3     -0.398577 -0.273697 -0.394789
# s4      0.617857  0.417212  0.430453
# s5      1.000000  0.464670  0.565883
# s6      0.464670  1.000000  0.382483
# Target  0.565883  0.382483  1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df[numeric_cols].corr(), annot=True)

# %%
plt.figure(figsize=(18,25))
sns.heatmap(df[numeric_cols].corr()
           [(df[numeric_cols].corr() >= 0.3) & (df[numeric_cols].corr() <= 0.5)],
            annot=True)

# %%
fig, ax = plt.subplots(3,3, figsize=(18,12))
for i, ax in enumerate(fig.axes):
    if i < 9:
        sns.regplot(x=df[numeric_cols[i]], y="Target", data=df, ax=ax)
